# %%
import pandas
dfALL = pandas.read_csv("drugReviews_20221217_817.csv")
dfALL.describe()
dfALL.shape
# Out:
# (215063, 6)

# %%
dfALL
# Out:
#                   drugName                     condition  dateReview  \
# 0              Mirtazapine                    Depression  2012-02-28
# 1               Mesalamine  Crohn's Disease, Maintenance  2009-05-17
# 2                  Bactrim       Urinary Tract Infection  2017-09-29
# 3                 Contrave                   Weight Loss  2017-03-05
# 4          Cyclafem 1 / 35                 Birth Control  2015-10-22
# ...                    ...                           ...         ...
# 215058             Campral            Alcohol Dependence  2015-05-31
# 215059      Metoclopramide               Nausea/Vomiting  2011-11-01
# 215060             Orencia          Rheumatoid Arthritis  2014-03-15
# 215061  Thyroid desiccated           Underactive Thyroid  2015-09-19
# 215062        Lubiprostone         Constipation, Chronic  2014-12-13
#
#                                                    review  rating  usefulCount
# 0       "I&#039;ve tried a few antidepressants over th...    10.0           22
# 1       "My son has Crohn&#039;s disease and has done ...     8.0           17
# 2                           "Quick reduction of symptoms"     9.0            3
# 3       "Contrave combines drugs that were used for al...     9.0           35
# 4       "I have been on this birth control for one cyc...     9.0            4
# ...                                                   ...     ...          ...
# 215058  "I wrote my first report in Mid-October of 201...    10.0          125
# 215059  "I was given this in IV before surgey. I immed...     1.0           34
# 215060  "Limited improvement after 4 months, developed...     2.0           35
# 215061  "I&#039;ve been on thyroid medication 49 years...    10.0           79
# 215062  "I&#039;ve had chronic constipation all my adu...     9.0          116
#
# [215063 rows x 6 columns]

# %%
dfALL.isna().sum()
# Out:
# drugName          0
# condition      1194
# dateReview        0
# review            0
# rating          570
# usefulCount       0
# dtype: int64

# %%
dfALL = dfALL.dropna( subset=["rating"] )
dfALL = dfALL.dropna( subset=["condition"] )

# %%
dfALL.describe()
# Out:
#               rating    usefulCount
# count  213301.000000  213301.000000
# mean        6.991364      28.096540
# std         3.275587      36.411323
# min         1.000000       0.000000
# 25%         5.000000       6.000000
# 50%         8.000000      16.000000
# 75%        10.000000      36.000000
# max        10.000000    1291.000000

# %%
df = dfALL.sample(n=1000)

# %%
df.review
# Out:
# 161393    "For me Midrin is very hit or miss, when I tak...
# 119851    "Have 24/7 headache ( nonspecific ) from what ...
# 177772    "My initial experience  with Brintellix is ver...
# 154558    "I&#039;m suffering from severe tendonitis/art...
# 20879     "I&#039;ve been on this pill for almost 4 mont...
#                                 ...
# 14192     "I have been on Trulicity for 3 weeks and I lo...
# 55229     "I was deeply suicidal for 15 years with repet...
# 129093    "I was diagnosed with rheumatoid arthritis in ...
# 163893    "Having read all reviews onsite I went ahead a...
# 111438    "This drug is highly addictive and due to it b...
# Name: review, Length: 1000, dtype: object

# %%
from sklearn.feature_extraction.text import CountVectorizer
tf_vectorizer = CountVectorizer( max_features=1000, stop_words="english" )
tfreview = tf_vectorizer.fit_transform( df.review )

# %%
from sklearn.decomposition import LatentDirichletAllocation
modelLda = LatentDirichletAllocation( n_components=10, n_jobs=-1 )
matrixLda = modelLda.fit_transform( tfreview )

# %%
print( matrixLda[ 1:5, ].round( 2 ) )
# Out:
# [[0.   0.   0.   0.   0.   0.   0.   0.   0.98 0.  ]
#  [0.65 0.   0.   0.   0.   0.   0.2  0.14 0.   0.  ]
#  [0.   0.62 0.   0.   0.36 0.   0.   0.   0.   0.  ]
#  [0.   0.04 0.   0.   0.   0.   0.33 0.   0.   0.61]]

# %%
df.review[ matrixLda[:,0] > 0.98 ]
# Out:
# 55410     "This medicine is amazing. I was a smoker for ...
# 33191     "I&#039;ve always had a problem with my undera...
# 161243    "I love this drug for several reasons: it real...
# 68614     "I have been suffering from the anxiety for th...
# 5845      "I am using minox for 4 months , it worked a l...
# 86972     "I&#039;ve taken royal jelly for years &amp; h...
# 2704      "I have ADHD and Bulimia. I read through every...
# 18908     "I was put on Zoloft a few years ago when I be...
# 11167     "I started smoking when I was 15 and quit when...
# Name: review, dtype: object

# %%
import matplotlib
from matplotlib import pyplot
def displayTopWords( model, feature_names, n_top_words, title ):
    fig, axes = matplotlib.pyplot.subplots(2, 5, figsize=(30, 15), sharex=True)
    axes = axes.flatten()
    for topic_idx, topic in enumerate(model.components_):
        top_features_ind = topic.argsort()[: -n_top_words - 1 : -1]
        top_features = [feature_names[i] for i in top_features_ind]
        weights = topic[top_features_ind]
        ax = axes[topic_idx]
        ax.barh(top_features, weights, height=0.7)
        ax.set_title(f"{title} {topic_idx +1}" )
        ax.invert_yaxis()
        ax.tick_params(axis="both", which="major" )
    matplotlib.pyplot.subplots_adjust(top=0.90, bottom=0.05, wspace=0.90, hspace=0.3)
    matplotlib.pyplot.show()

# %%
displayTopWords( modelLda, tf_vectorizer.get_feature_names_out(), 10, "LDA" )

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
tfidf_vectorizer = TfidfVectorizer( max_features=1000, stop_words="english" )
tfidfreview = tfidf_vectorizer.fit_transform( df.review )

# %%
from sklearn.decomposition import NMF
modelMnf = NMF( n_components=10, max_iter=1000 )
matrixMnf = modelMnf.fit_transform( tfidfreview)

# %%
print( matrixMnf[ 1:5, ].round( 3 ) )
# Out:
# [[0.044 0.128 0.032 0.02  0.    0.004 0.001 0.    0.002 0.09 ]
#  [0.    0.    0.    0.15  0.129 0.    0.141 0.108 0.    0.064]
#  [0.019 0.15  0.    0.022 0.    0.008 0.162 0.005 0.    0.   ]
#  [0.026 0.05  0.16  0.106 0.    0.    0.    0.    0.    0.   ]]

# %%
df.review[ matrixMnf[:,0] > 0.11 ]
# Out:
# 188519    "I had sex on the day of my ovulation. I took ...
# 161109    "Hi, I am also here to share my experience of ...
# 45295     "I have been on Viberzi for 4 full days now. s...
# 54901     "After breaking both ankles in 1987, I was dia...
# 85320     "Got my free sample of salonpas pain patch the...
# 55410     "This medicine is amazing. I was a smoker for ...
# 16920     "I had unprotected sex and I took  Next Choice...
# 25837     "Have been on Azathioprine for about 4 years a...
# 90611     "I took it for five months every day , I did n...
# 176929    "I have been constipated for over 20 years. Re...
# 101238    "Took two pills a day for ten days, and starte...
# 173774    "I&#039;m on this medication after developing ...
# 108595    "By far the worst drug ever made. This drug is...
# 175591    "I took a full pill the first day, which was s...
# 203571    "I took plan b about 2 weeks ago my partner wa...
# 142150    "I started ALLI on Saturday 16th. I took all 3...
# 18863     "Started a 10 day regimen 3 days ago for a sin...
# 48230     "I thought I was finally going to find the med...
# 112060    "This is an evil little pill!  The first time ...
# 47319     "Been having constipation for over a year due ...
# 75558     "I had a persistent cough for 8 weeks (muscle ...
# 89096     "Used oral for UTI and All the side effects ju...
# 96182     "Next Monday 5/22 makes 4 weeks on Harvoni.  T...
# 129949    "I was sick for a full 7 days and could not ea...
# 140239    "Linzess is a savior for me.  I took it for a ...
# 3438      "I was in hospital for extreme pain in my tumm...
# 42172     "Wasn&#039;t sleeping well and was having care...
# 210046    "Didn&#039;t work for me. Made me nauseous. I ...
# 5761      "I was prescribed 2.5 mg/day Abilify to augmen...
# 176772    "The day after my first injection, I was so ex...
# 197331    "I was prescribed this medication after years ...
# 45030     "4years quit, after 30 years smoking. I really...
# 131124    "I am taking keflex to keep from getting an in...
# 171611    "Have taken lorazepam now for a year only on a...
# 31131     "Me and my boyfriend were having sex and the c...
# 11167     "I started smoking when I was 15 and quit when...
# Name: review, dtype: object

# %%
displayTopWords( modelMnf, tfidf_vectorizer.get_feature_names_out(), 10, "NMF" )

# %%
import nltk
nltk.download('vader_lexicon')
from nltk.sentiment import SentimentIntensityAnalyzer
sia = SentimentIntensityAnalyzer()
df['sentiment'] = [sia.polarity_scores(x)['compound'] for x in df['review']]
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\Ahern\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
df["date"] = pandas.to_datetime(df.dateReview, format="%Y/%m/%d")

# %%
df[ "Year" ] = df.date.dt.year
df[ "Month" ] = df.date.dt.month_name()
df[ "Day" ] = df.date.dt.day_name()

# %%
df
# Out:
#                                                  drugName  \
# 161393  Acetaminophen / dichloralphenazone / isomethep...
# 119851                                         Gabapentin
# 177772                                         Trintellix
# 154558                                          Mupirocin
# 20879                   Ethinyl estradiol / norethindrone
# ...                                                   ...
# 14192                                           Trulicity
# 55229                                              Latuda
# 129093                                        Tocilizumab
# 163893                                           Implanon
# 111438                                          Lorazepam
#
#                                       condition  dateReview  \
# 161393                                 Headache  2017-04-11
# 119851                                     Pain  2017-01-01
# 177772                               Depression  2014-08-17
# 154558  Nasal Carriage of Staphylococcus aureus  2009-09-20
# 20879                             Birth Control  2016-08-21
# ...                                         ...         ...
# 14192                          Diabetes, Type 2  2017-06-28
# 55229                           Bipolar Disorde  2015-12-25
# 129093                     Rheumatoid Arthritis  2013-03-28
# 163893                            Birth Control  2010-08-03
# 111438                                  Anxiety  2015-12-18
#
#                                                    review  rating  \
# 161393  "For me Midrin is very hit or miss, when I tak...     6.0
# 119851  "Have 24/7 headache ( nonspecific ) from what ...     8.0
# 177772  "My initial experience  with Brintellix is ver...     9.0
# 154558  "I&#039;m suffering from severe tendonitis/art...     5.0
# 20879   "I&#039;ve been on this pill for almost 4 mont...     1.0
# ...                                                   ...     ...
# 14192   "I have been on Trulicity for 3 weeks and I lo...    10.0
# 55229   "I was deeply suicidal for 15 years with repet...     9.0
# 129093  "I was diagnosed with rheumatoid arthritis in ...     9.0
# 163893  "Having read all reviews onsite I went ahead a...     7.0
# 111438  "This drug is highly addictive and due to it b...     2.0
#
#         usefulCount  sentiment       date  Year      Month        Day
# 161393            2    -0.6204 2017-04-11  2017      April    Tuesday
# 119851           48    -0.8957 2017-01-01  2017    January     Sunday
# 177772          266    -0.7703 2014-08-17  2014     August     Sunday
# 154558           20    -0.9800 2009-09-20  2009  September     Sunday
# 20879             6    -0.8092 2016-08-21  2016     August     Sunday
# ...             ...        ...        ...   ...        ...        ...
# 14192            16     0.4588 2017-06-28  2017       June  Wednesday
# 55229            33    -0.9383 2015-12-25  2015   December     Friday
# 129093          144    -0.7685 2013-03-28  2013      March   Thursday
# 163893            2     0.8359 2010-08-03  2010     August    Tuesday
# 111438           29     0.1747 2015-12-18  2015   December     Friday
#
# [1000 rows x 11 columns]

# %%
import numpy
rng = numpy.random.RandomState( 28 )
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split( df, df.usefulCount, random_state=rng, test_size=0.5 )

# %%
lstNum = [ 'rating', 'sentiment']
lstCat = ['Year', 'Month', 'Day']

# %%
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler
pipeNum = Pipeline( [
    ("selector", ColumnTransformer([ ("selector", "passthrough", lstNum ) ] )),
    ('scaler', StandardScaler() )
    ])
from sklearn.preprocessing import OneHotEncoder
pipeCat = Pipeline([
    ('selector', ColumnTransformer([ ("selector", "passthrough", lstCat ) ] )),
    ('encoder', OneHotEncoder( dtype=int, drop="first", handle_unknown='ignore' ) )
    ])

# %%
from sklearn.pipeline import FeatureUnion
preprocessorBase = FeatureUnion([
    ('cat', pipeCat ),
    ('num', pipeNum )
    ])

# %%
from xgboost import XGBRegressor
pipeBase = Pipeline([
    ('preprocessor', preprocessorBase ),
    ('model', XGBRegressor() )
    ])

# %%
df
# Out:
#                                                  drugName  \
# 161393  Acetaminophen / dichloralphenazone / isomethep...
# 119851                                         Gabapentin
# 177772                                         Trintellix
# 154558                                          Mupirocin
# 20879                   Ethinyl estradiol / norethindrone
# ...                                                   ...
# 14192                                           Trulicity
# 55229                                              Latuda
# 129093                                        Tocilizumab
# 163893                                           Implanon
# 111438                                          Lorazepam
#
#                                       condition  dateReview  \
# 161393                                 Headache  2017-04-11
# 119851                                     Pain  2017-01-01
# 177772                               Depression  2014-08-17
# 154558  Nasal Carriage of Staphylococcus aureus  2009-09-20
# 20879                             Birth Control  2016-08-21
# ...                                         ...         ...
# 14192                          Diabetes, Type 2  2017-06-28
# 55229                           Bipolar Disorde  2015-12-25
# 129093                     Rheumatoid Arthritis  2013-03-28
# 163893                            Birth Control  2010-08-03
# 111438                                  Anxiety  2015-12-18
#
#                                                    review  rating  \
# 161393  "For me Midrin is very hit or miss, when I tak...     6.0
# 119851  "Have 24/7 headache ( nonspecific ) from what ...     8.0
# 177772  "My initial experience  with Brintellix is ver...     9.0
# 154558  "I&#039;m suffering from severe tendonitis/art...     5.0
# 20879   "I&#039;ve been on this pill for almost 4 mont...     1.0
# ...                                                   ...     ...
# 14192   "I have been on Trulicity for 3 weeks and I lo...    10.0
# 55229   "I was deeply suicidal for 15 years with repet...     9.0
# 129093  "I was diagnosed with rheumatoid arthritis in ...     9.0
# 163893  "Having read all reviews onsite I went ahead a...     7.0
# 111438  "This drug is highly addictive and due to it b...     2.0
#
#         usefulCount  sentiment       date  Year      Month        Day
# 161393            2    -0.6204 2017-04-11  2017      April    Tuesday
# 119851           48    -0.8957 2017-01-01  2017    January     Sunday
# 177772          266    -0.7703 2014-08-17  2014     August     Sunday
# 154558           20    -0.9800 2009-09-20  2009  September     Sunday
# 20879             6    -0.8092 2016-08-21  2016     August     Sunday
# ...             ...        ...        ...   ...        ...        ...
# 14192            16     0.4588 2017-06-28  2017       June  Wednesday
# 55229            33    -0.9383 2015-12-25  2015   December     Friday
# 129093          144    -0.7685 2013-03-28  2013      March   Thursday
# 163893            2     0.8359 2010-08-03  2010     August    Tuesday
# 111438           29     0.1747 2015-12-18  2015   December     Friday
#
# [1000 rows x 11 columns]

# %%
pipeBase.fit( X_train, y_train )
import sklearn.metrics
predTestBase = pipeBase.predict( X_test )
sklearn.metrics.r2_score( y_test, predTestBase )
# Out:
# -0.1263415398669343

# %%
pipeTextLda = Pipeline([
    ('selector', ColumnTransformer([ ("selector",
    CountVectorizer( max_features=1000, stop_words="english" ),
    'review' ) ] ) ),
    ('topic', LatentDirichletAllocation( n_components=10 ) ),
    ])
preprocessorLda = FeatureUnion([
    ('cat', pipeCat ),
    ('text', pipeTextLda ),
    ('num', pipeNum )
    ])
pipeLda = Pipeline([
    ('preprocessor', preprocessorLda ),
    ('model', XGBRegressor() )
    ])

# %%
pipeLda.fit( X_train, y_train )
predTestLda = pipeLda.predict( X_test )
sklearn.metrics.r2_score( y_test, predTestLda )
# Out:
# -0.06332854408804978

# %%
pipeTextNmf = Pipeline([
    ('selector', ColumnTransformer([ ("selector",
    TfidfVectorizer( max_features=1000, stop_words="english" ),
    'review' ) ] ) ),
    ('topic', NMF( n_components=10, max_iter=2000 ) ),
    ])
preprocessorNmf = FeatureUnion([
    ('cat', pipeCat ),
    ('text', pipeTextNmf ),
    ('num', pipeNum )
    ])
pipeNmf = Pipeline([
    ('preprocessor', preprocessorNmf ),
    ('model', XGBRegressor() )
    ])

# %%
pipeLda.fit( X_train, y_train )
predTestLda = pipeLda.predict( X_test )
sklearn.metrics.r2_score( y_test, predTestLda )
# Out:
# -0.001975213405772447

# %%
dfOtezla = df[(df.drugName == 'Otezla')]

# %%
dfOtezla
# Out:
# Empty DataFrame
# Columns: [drugName, condition, dateReview, review, rating, usefulCount, sentiment, date, Year, Month, Day]
# Index: []
