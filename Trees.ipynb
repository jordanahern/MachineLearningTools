# %%
get_ipython().ast_node_interactivity = 'all'

# %%
import pandas
df = pandas.read_csv( "creditCardDefault.csv" )
df.shape
df
# Out:
# (30000, 24)
#        Limit_Bal  Education Marriage  Age  Pay_0  Pay_2  Pay_3  Pay_4  Pay_5  \
# 0          20000          2  married   24      2      2     -1     -1     -2
# 1         120000          2   single   26     -1      2      0      0      0
# 2          90000          2   single   34      0      0      0      0      0
# 3          50000          2  married   37      0      0      0      0      0
# 4          50000          2  married   57     -1      0     -1      0      0
# ...          ...        ...      ...  ...    ...    ...    ...    ...    ...
# 29995     220000          3  married   39      0      0      0      0      0
# 29996     150000          3   single   43     -1     -1     -1     -1      0
# 29997      30000          2   single   37      4      3      2     -1      0
# 29998      80000          3  married   41      1     -1      0      0      0
# 29999      50000          2  married   46      0      0      0      0      0
#
# ...

# %%
df.describe()
hist = df.Payment.hist()
# Out:
#             Limit_Bal     Education           Age         Pay_0         Pay_2  \
# count    30000.000000  30000.000000  30000.000000  30000.000000  30000.000000
# mean    167484.322667      1.853133     35.485500     -0.016700     -0.133767
# std     129747.661567      0.790349      9.217904      1.123802      1.197186
# min      10000.000000      0.000000     21.000000     -2.000000     -2.000000
# 25%      50000.000000      1.000000     28.000000     -1.000000     -1.000000
# 50%     140000.000000      2.000000     34.000000      0.000000      0.000000
# 75%     240000.000000      2.000000     41.000000      0.000000      0.000000
# max    1000000.000000      6.000000     79.000000      8.000000      8.000000
#
#               Pay_3         Pay_4         Pay_5         Pay_6      Bill_Amt1  \
# count  30000.000000  30000.000000  30000.000000  30000.000000   30000.000000
# mean      -0.166200     -0.220667     -0.266200     -0.291100   51223.330900
# ...

# %%
import numpy
rng = numpy.random.RandomState( 28 )
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test =train_test_split( df, df.Payment, random_state=rng, test_size=0.5 )

# %%
lstNum = [ 'Limit_Bal', 'Age', 'Bill_Amt1', 'Pay_Amt1' ]
lstCat = [ 'Card', 'Marriage', 'Pay_0' ]

# %%
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler
pipeNum = Pipeline( [
    ('selector', ColumnTransformer([ ('selector', 'passthrough', lstNum ) ] )),
    ('scaler', StandardScaler() )
])

# %%
from sklearn.preprocessing import OneHotEncoder
pipeCat = Pipeline([
    ('selector', ColumnTransformer([ ('selector', 'passthrough', lstCat ) ] )),
    ('encoder', OneHotEncoder( dtype=int, drop='first' ) )
])

# %%
from sklearn.pipeline import FeatureUnion
preprocessor = FeatureUnion([
    ('cat', pipeCat ),
    ('num', pipeNum )
])

# %%
from sklearn.linear_model import LogisticRegression
pipe = Pipeline([
    ('preprocessor', preprocessor ),
    ('model', LogisticRegression( max_iter = 200 ) )
    ])

# %%
pipe.fit( X_train, y_train )
# Out:
# Pipeline(steps=[('preprocessor',
#                  FeatureUnion(transformer_list=[('cat',
#                                                  Pipeline(steps=[('selector',
#                                                                   ColumnTransformer(transformers=[('selector',
#                                                                                                    'passthrough',
#                                                                                                    ['Card',
#                                                                                                     'Marriage',
#                                                                                                     'Pay_0'])])),
#                                                                  ('encoder',
#                                                                   OneHotEncoder(drop='first',
# ...

# %%
import sklearn.metrics
predTrain = pipe.predict( X_train )

# %%
# sklearn.metrics.r2_score( y_train, predTrain )
# wont work, as we cant use numeric oriented measures in a classification (logistic) problem

# %%
pandas.value_counts( y_train )
pandas.value_counts( predTrain )
# Out:
# Paid      11616
# Missed     3384
# Name: Payment, dtype: int64
# Paid      13431
# Missed     1569
# dtype: int64

# %%
sklearn.metrics.confusion_matrix( y_train, predTrain )
# Out:
# array([[ 1099,  2285],
#        [  470, 11146]], dtype=int64)

# %%
sklearn.metrics.accuracy_score( y_train, predTrain )
sklearn.metrics.cohen_kappa_score( y_train, predTrain )
sklearn.metrics.precision_score( y_train, predTrain, pos_label="Paid" )
sklearn.metrics.recall_score( y_train, predTrain, pos_label="Paid" )
sklearn.metrics.f1_score( y_train, predTrain, pos_label="Paid" )
# Out:
# 0.8163333333333334
# 0.35101145159727987
# 0.8298711935075571
# 0.959538567493113
# 0.8900067872399888

# %%
print( sklearn.metrics.classification_report( y_train, predTrain ) )
# Out:
#               precision    recall  f1-score   support
#
#       Missed       0.70      0.32      0.44      3384
#         Paid       0.83      0.96      0.89     11616
#
#     accuracy                           0.82     15000
#    macro avg       0.77      0.64      0.67     15000
# weighted avg       0.80      0.82      0.79     15000

# %%
from mlxtend.preprocessing import DenseTransformer
pipeLogistic = Pipeline([
    ('preprocessor', preprocessor ),
    ('todense', DenseTransformer() ),
    ('model', LogisticRegression( max_iter = 200 ) )
    ], verbose=True )

# %%
pipeLogistic.fit( X_train, y_train)
# Out:
# [Pipeline] ...... (step 1 of 3) Processing preprocessor, total=   0.0s
# [Pipeline] ........... (step 2 of 3) Processing todense, total=   0.0s
# [Pipeline] ............. (step 3 of 3) Processing model, total=   0.1s
# Pipeline(steps=[('preprocessor',
#                  FeatureUnion(transformer_list=[('cat',
#                                                  Pipeline(steps=[('selector',
#                                                                   ColumnTransformer(transformers=[('selector',
#                                                                                                    'passthrough',
#                                                                                                    ['Card',
#                                                                                                     'Marriage',
#                                                                                                     'Pay_0'])])),
# ...

# %%
predTrainLogistic = pipeLogistic.predict( X_train )
predTestLogistic = pipeLogistic.predict( X_test )

# %%
print( sklearn.metrics.classification_report( y_train, predTrainLogistic ) )
sklearn.metrics.cohen_kappa_score( y_train, predTrainLogistic )
sklearn.metrics.cohen_kappa_score( y_test, predTestLogistic )
# Out:
#               precision    recall  f1-score   support
#
#       Missed       0.70      0.32      0.44      3384
#         Paid       0.83      0.96      0.89     11616
#
#     accuracy                           0.82     15000
#    macro avg       0.77      0.64      0.67     15000
# weighted avg       0.80      0.82      0.79     15000
# 0.35101145159727987
# 0.34697041283810615

# %%
from sklearn.metrics import ConfusionMatrixDisplay
cmLogistic = sklearn.metrics.confusion_matrix( y_train, predTrainLogistic )
plotCmLogistic = sklearn.metrics.ConfusionMatrixDisplay( cmLogistic, display_labels=pipeLogistic.
classes_ ).plot()

#display_lables is optional, adds lables to what would be true false

# %%
from sklearn.naive_bayes import GaussianNB
pipeNb = Pipeline([
    ('preprocessor', preprocessor ),
    ('model', GaussianNB() )
    ], verbose=True )

# %%
#pipeNb.fit( X_train, y_train) # gives an error

# %%
pipeNb = Pipeline([
    ('preprocessor', preprocessor ),
    ('todense', DenseTransformer() ),
    ('model', GaussianNB() )
    ], verbose=True )

# %%
pipeNb.fit( X_train, y_train )
# Out:
# [Pipeline] ...... (step 1 of 3) Processing preprocessor, total=   0.0s
# [Pipeline] ........... (step 2 of 3) Processing todense, total=   0.0s
# [Pipeline] ............. (step 3 of 3) Processing model, total=   0.0s
# Pipeline(steps=[('preprocessor',
#                  FeatureUnion(transformer_list=[('cat',
#                                                  Pipeline(steps=[('selector',
#                                                                   ColumnTransformer(transformers=[('selector',
#                                                                                                    'passthrough',
#                                                                                                    ['Card',
#                                                                                                     'Marriage',
#                                                                                                     'Pay_0'])])),
# ...

# %%
predTrainNb = pipeNb.predict( X_train )
predTestNb = pipeNb.predict( X_test )

# %%
print( sklearn.metrics.classification_report( y_train, predTrainLogistic ) )
print( sklearn.metrics.classification_report( y_train, predTrainNb ) )
sklearn.metrics.cohen_kappa_score( y_train, predTrainLogistic )
sklearn.metrics.cohen_kappa_score( y_test, predTestLogistic )
sklearn.metrics.cohen_kappa_score( y_train, predTrainNb )
sklearn.metrics.cohen_kappa_score( y_test, predTestNb )
# Out:
#               precision    recall  f1-score   support
#
#       Missed       0.70      0.32      0.44      3384
#         Paid       0.83      0.96      0.89     11616
#
#     accuracy                           0.82     15000
#    macro avg       0.77      0.64      0.67     15000
# weighted avg       0.80      0.82      0.79     15000
#
#               precision    recall  f1-score   support
#
#       Missed       0.66      0.34      0.45      3384
#         Paid       0.83      0.95      0.89     11616
#
#     accuracy                           0.81     15000
#    macro avg       0.75      0.65      0.67     15000
# weighted avg       0.79      0.81      0.79     15000
# 0.35101145159727987
# 0.34697041283810615
# 0.35024792383367087
# 0.3428747819310707

# %%
cmLogistic = sklearn.metrics.confusion_matrix( y_train, predTrainLogistic )
plotCmLogistic = sklearn.metrics.ConfusionMatrixDisplay( cmLogistic, display_labels=pipeLogistic.
classes_ ).plot()
cmNb = sklearn.metrics.confusion_matrix( y_train, predTrainNb )
plotCmNb = sklearn.metrics.ConfusionMatrixDisplay( cmNb, display_labels=pipeNb.classes_ ).plot()

# %%
from sklearn.svm import LinearSVC
pipeSvm = Pipeline([
    ('preprocessor', preprocessor ),
    ('todense', DenseTransformer() ),
    ('model', LinearSVC( tol = 0.01, max_iter=5000 ) )
    ], verbose=True )

# %%
pipeSvm.fit( X_train, y_train )
# Out:
# [Pipeline] ...... (step 1 of 3) Processing preprocessor, total=   0.0s
# [Pipeline] ........... (step 2 of 3) Processing todense, total=   0.0s
# [Pipeline] ............. (step 3 of 3) Processing model, total=   2.5s
# Pipeline(steps=[('preprocessor',
#                  FeatureUnion(transformer_list=[('cat',
#                                                  Pipeline(steps=[('selector',
#                                                                   ColumnTransformer(transformers=[('selector',
#                                                                                                    'passthrough',
#                                                                                                    ['Card',
#                                                                                                     'Marriage',
#                                                                                                     'Pay_0'])])),
# ...

# %%
predTrainSvm = pipeSvm.predict( X_train )
predTestSvm = pipeSvm.predict( X_test )

# %%
print( sklearn.metrics.classification_report( y_train, predTrainSvm ) )
# Out:
#               precision    recall  f1-score   support
#
#       Missed       0.70      0.33      0.45      3384
#         Paid       0.83      0.96      0.89     11616
#
#     accuracy                           0.82     15000
#    macro avg       0.77      0.64      0.67     15000
# weighted avg       0.80      0.82      0.79     15000

# %%
>>> cmLogistic = sklearn.metrics.confusion_matrix( y_train, predTrainLogistic )
>>> plotCmLogistic = sklearn.metrics.ConfusionMatrixDisplay( cmLogistic, display_labels=pipeLogistic.
classes_ ).plot()
>>> cmNb = sklearn.metrics.confusion_matrix( y_train, predTrainNb )
>>> plotCmNb = sklearn.metrics.ConfusionMatrixDisplay( cmNb, display_labels=pipeNb.classes_ ).plot()

>>> cmSvm = sklearn.metrics.confusion_matrix( y_train, predTrainSvm )
>>> plotCmSvm = sklearn.metrics.ConfusionMatrixDisplay( cmSvm, display_labels=pipeSvm.classes_ ).plot()

# %%
rocSvm = sklearn.metrics.RocCurveDisplay.from_estimator( pipeSvm, X_train, y_train )

# %%
## NEW CLASS STARTS BELOW HERE

# %%
from sklearn.tree import DecisionTreeClassifier

pipeDt = Pipeline([
    ('preprocessor', preprocessor ),
    ('model', DecisionTreeClassifier() )
    ], verbose=True )

# %%
pipeDt.fit( X_train, y_train)
# Out:
# [Pipeline] ...... (step 1 of 2) Processing preprocessor, total=   0.0s
# [Pipeline] ............. (step 2 of 2) Processing model, total=   0.3s
# Pipeline(steps=[('preprocessor',
#                  FeatureUnion(transformer_list=[('cat',
#                                                  Pipeline(steps=[('selector',
#                                                                   ColumnTransformer(transformers=[('selector',
#                                                                                                    'passthrough',
#                                                                                                    ['Card',
#                                                                                                     'Marriage',
#                                                                                                     'Pay_0'])])),
#                                                                  ('encoder',
# ...

# %%
predTrainDt = pipeDt.predict( X_train )
predTestDt = pipeDt.predict( X_test )

# %%
sklearn.metrics.cohen_kappa_score( y_train, predTrainDt )
# Out:
# 0.9942808443974847

# %%
print( sklearn.metrics.classification_report( y_train, predTrainDt ) )
# Out:
#               precision    recall  f1-score   support
#
#       Missed       0.99      1.00      1.00      3384
#         Paid       1.00      1.00      1.00     11616
#
#     accuracy                           1.00     15000
#    macro avg       1.00      1.00      1.00     15000
# weighted avg       1.00      1.00      1.00     15000

# %%
cmDt = sklearn.metrics.confusion_matrix( y_train, predTrainDt )
plotCmDt = sklearn.metrics.ConfusionMatrixDisplay( cmDt, display_labels=pipeDt.classes_ ).plot()

# %%
from sklearn.tree import plot_tree
plotTree = sklearn.tree.plot_tree( pipeDt['model'], max_depth=10 )

# %%
plotTree = sklearn.tree.plot_tree( pipeDt['model'], max_depth=2 )

# %%
tempFeatures = pipeDt[:-1].get_feature_names_out()
plotTree = sklearn.tree.plot_tree( pipeDt['model'], max_depth=2, feature_names = tempFeatures )

# %%
sklearn.metrics.cohen_kappa_score( y_test, predTestDt )
# Out:
# 0.20152404707910931

# %%
print( sklearn.metrics.classification_report( y_test, predTestDt ) )
# Out:
#               precision    recall  f1-score   support
#
#       Missed       0.37      0.39      0.38      3252
#         Paid       0.83      0.81      0.82     11748
#
#     accuracy                           0.72     15000
#    macro avg       0.60      0.60      0.60     15000
# weighted avg       0.73      0.72      0.73     15000

# %%
cmDtTest = sklearn.metrics.confusion_matrix( y_test, predTestDt )

plotCmDtTest = sklearn.metrics.ConfusionMatrixDisplay( cmDtTest, display_labels=pipeDt.classes_ ).plot()

# %%
from sklearn.ensemble import BaggingClassifier
pipeBagDt = Pipeline([
    ('preprocessor', preprocessor ),
    ('model', BaggingClassifier( DecisionTreeClassifier(), max_samples=0.5 ) )
    ], verbose=True )

# %%
pipeBagDt.fit( X_train, y_train )
# Out:
# [Pipeline] ...... (step 1 of 2) Processing preprocessor, total=   0.0s
# [Pipeline] ............. (step 2 of 2) Processing model, total=   1.0s
# Pipeline(steps=[('preprocessor',
#                  FeatureUnion(transformer_list=[('cat',
#                                                  Pipeline(steps=[('selector',
#                                                                   ColumnTransformer(transformers=[('selector',
#                                                                                                    'passthrough',
#                                                                                                    ['Card',
#                                                                                                     'Marriage',
#                                                                                                     'Pay_0'])])),
#                                                                  ('encoder',
# ...

# %%
predTrainBagDt = pipeBagDt.predict( X_train )
predTestBagDt = pipeBagDt.predict( X_test )

# %%
sklearn.metrics.cohen_kappa_score( y_train, predTrainDt )
sklearn.metrics.cohen_kappa_score( y_train, predTrainBagDt )
# Out:
# 0.9942808443974847
# 0.7794783807328897

# %%
sklearn.metrics.cohen_kappa_score( y_test, predTestDt )
sklearn.metrics.cohen_kappa_score( y_test, predTestBagDt )
# Out:
# 0.20152404707910931
# 0.3334728489080355

# %%
from sklearn.ensemble import RandomForestClassifier
pipeRf = Pipeline([
    ('preprocessor', preprocessor ),
    ('model', RandomForestClassifier() )
    ], verbose=True )

# %%
pipeRf.fit( X_train, y_train )
# Out:
# [Pipeline] ...... (step 1 of 2) Processing preprocessor, total=   0.0s
# [Pipeline] ............. (step 2 of 2) Processing model, total=  10.8s
# Pipeline(steps=[('preprocessor',
#                  FeatureUnion(transformer_list=[('cat',
#                                                  Pipeline(steps=[('selector',
#                                                                   ColumnTransformer(transformers=[('selector',
#                                                                                                    'passthrough',
#                                                                                                    ['Card',
#                                                                                                     'Marriage',
#                                                                                                     'Pay_0'])])),
#                                                                  ('encoder',
# ...

# %%
predTrainRf = pipeRf.predict( X_train )
predTestRf = pipeRf.predict( X_test )

# %%
sklearn.metrics.cohen_kappa_score( y_train, predTrainDt )
sklearn.metrics.cohen_kappa_score( y_train, predTrainBagDt )
sklearn.metrics.cohen_kappa_score( y_train, predTrainRf )
# Out:
# 0.9942808443974847
# 0.7794783807328897
# 0.9940747079175053

# %%
sklearn.metrics.cohen_kappa_score( y_test, predTestDt )
sklearn.metrics.cohen_kappa_score( y_test, predTestBagDt )
sklearn.metrics.cohen_kappa_score( y_test, predTestRf )
# Out:
# 0.20152404707910931
# 0.3334728489080355
# 0.3405199234526157

# %%
rfBar = pandas.Series( pipeRf[ "model" ].feature_importances_, index=pipeRf[:-1].
get_feature_names_out() ).plot.barh()

# %%
from sklearn.ensemble import AdaBoostClassifier


pipeAda = Pipeline([
    ('preprocessor', preprocessor ),
    ('model', AdaBoostClassifier() )
    ], verbose=True )

# %%
pipeAda.fit( X_train, y_train )
predTrainAda = pipeAda.predict( X_train )
predTestAda = pipeAda.predict( X_test )
# Out:
# [Pipeline] ...... (step 1 of 2) Processing preprocessor, total=   0.0s
# [Pipeline] ............. (step 2 of 2) Processing model, total=   1.2s
# Pipeline(steps=[('preprocessor',
#                  FeatureUnion(transformer_list=[('cat',
#                                                  Pipeline(steps=[('selector',
#                                                                   ColumnTransformer(transformers=[('selector',
#                                                                                                    'passthrough',
#                                                                                                    ['Card',
#                                                                                                     'Marriage',
#                                                                                                     'Pay_0'])])),
#                                                                  ('encoder',
# ...

# %%
sklearn.metrics.cohen_kappa_score( y_train, predTrainDt )

sklearn.metrics.cohen_kappa_score( y_train, predTrainBagDt )

sklearn.metrics.cohen_kappa_score( y_train, predTrainRf )

sklearn.metrics.cohen_kappa_score( y_train, predTrainAda)
# Out:
# 0.9942808443974847
# 0.7794783807328897
# 0.9940747079175053
# 0.3620734965779966

# %%
sklearn.metrics.cohen_kappa_score( y_test, predTestDt )

sklearn.metrics.cohen_kappa_score( y_test, predTestBagDt )

sklearn.metrics.cohen_kappa_score( y_test, predTestRf )

sklearn.metrics.cohen_kappa_score( y_test,predTestAda )
# Out:
# 0.20152404707910931
# 0.3334728489080355
# 0.3405199234526157
# 0.3562153613517657

# %%
from sklearn.ensemble import GradientBoostingClassifier

# %%
pipeGb = Pipeline([
('preprocessor', preprocessor ),
    ('model', GradientBoostingClassifier() )
    ], verbose=True )

# %%
pipeGb.fit( X_train, y_train )
# Out:
# [Pipeline] ...... (step 1 of 2) Processing preprocessor, total=   0.0s
# [Pipeline] ............. (step 2 of 2) Processing model, total=   2.2s
# Pipeline(steps=[('preprocessor',
#                  FeatureUnion(transformer_list=[('cat',
#                                                  Pipeline(steps=[('selector',
#                                                                   ColumnTransformer(transformers=[('selector',
#                                                                                                    'passthrough',
#                                                                                                    ['Card',
#                                                                                                     'Marriage',
#                                                                                                     'Pay_0'])])),
#                                                                  ('encoder',
# ...

# %%
predTrainGb = pipeGb.predict( X_train )
predTestGb = pipeGb.predict( X_test )

# %%
sklearn.metrics.cohen_kappa_score( y_train, predTrainDt )
sklearn.metrics.cohen_kappa_score( y_train, predTrainBagDt )
sklearn.metrics.cohen_kappa_score( y_train, predTrainRf )
sklearn.metrics.cohen_kappa_score( y_train, predTrainAda)
sklearn.metrics.cohen_kappa_score( y_train, predTrainGb )
# Out:
# 0.9942808443974847
# 0.7794783807328897
# 0.9940747079175053
# 0.3620734965779966
# 0.37187011987799057

# %%
sklearn.metrics.cohen_kappa_score( y_test, predTestDt )
sklearn.metrics.cohen_kappa_score( y_test, predTestBagDt )
sklearn.metrics.cohen_kappa_score( y_test, predTestRf )
sklearn.metrics.cohen_kappa_score( y_test, predTestAda )
sklearn.metrics.cohen_kappa_score( y_test, predTestGb )
# Out:
# 0.20152404707910931
# 0.3334728489080355
# 0.3405199234526157
# 0.3562153613517657
# 0.3547040980000046
